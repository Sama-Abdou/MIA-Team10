# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.0/617.0 kB 11.7 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/drive/MyDrive/Labeled/dataSet2.zip
# Out:
# Archive:  /content/drive/MyDrive/Labeled/dataSet2.zip
#    creating: dataSet/
#    creating: dataSet/train/
#    creating: dataSet/train/images/
#   inflating: dataSet/train/images/H125.jpg
#   inflating: dataSet/train/images/H129.jpg
#   inflating: dataSet/train/images/H18.jpg
#   inflating: dataSet/train/images/H19.jpg
#   inflating: dataSet/train/images/H20.jpg
#   inflating: dataSet/train/images/H23.jpg
#   inflating: dataSet/train/images/H30.jpg
#   inflating: dataSet/train/images/H41.jpg
#   inflating: dataSet/train/images/H43.jpg
#   inflating: dataSet/train/images/H44.jpg
#   inflating: dataSet/train/images/H54.jpg
#   inflating: dataSet/train/images/H79.jpg
#   inflating: dataSet/train/images/H80.jpg
#   inflating: dataSet/train/images/H88.jpg
#   inflating: dataSet/train/images/HQ133.jpg
#   inflating: dataSet/train/images/HQ134.jpg
#   inflating: dataSet/train/images/HQ135.jpg
#   inflating: dataSet/train/images/HQ136.jpg
#   inflating: dataSet/train/images/HQ59.jpg
# ...

# %%
# %cd /content/drive/MyDrive/Labeled
# Out:
# /content/drive/MyDrive/Labeled

# %%
# !yolo task=detect mode=train data=/content/dataSet.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 11.1MB/s]
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
